# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_path = "C://Users//User//OneDrive//Desktop//DS Practice//Sport//SPL-Open-Data-Rahul//P0001_shooting_alt.csv"

data = pd.read_csv(data_path)
data
# Out:
#       participant_id trial_id  result  landing_x  landing_y  entry_angle  \
# 0              P0001    T0001  missed       7.15     12.755         40.9
# 1              P0001    T0001  missed       7.15     12.755         40.9
# 2              P0001    T0001  missed       7.15     12.755         40.9
# 3              P0001    T0001  missed       7.15     12.755         40.9
# 4              P0001    T0001  missed       7.15     12.755         40.9
# ...              ...      ...     ...        ...        ...          ...
# 29995          P0001    T0125    made      -2.55      7.550         45.3
# 29996          P0001    T0125    made      -2.55      7.550         45.3
# 29997          P0001    T0125    made      -2.55      7.550         45.3
# 29998          P0001    T0125    made      -2.55      7.550         45.3
# 29999          P0001    T0125    made      -2.55      7.550         45.3
#
#        ball_x  ball_y  ball_z  R_EYE_x  ...  L_1STTOE_z  L_5THTOE_x  \
# ...

# %%
import numpy as np
import math

def angle_finder_shared(A, B, C, D):
    """
    Retrieves the angle between points, A,B,C,D by using the dot product. 

    When you have like a shared point, just use it again

    Args:
        A: (np.array) An array of size 3
        B: (np.array) An array of size 3
        C: (np.array) An array of size 3
        D: (np.array) An array of size 3
    
    Return:
        angle: (np.float) the angle between the 3 points
    """
    A_B = A-B
    D_C = C-D

    dotproduct = np.dot(A_B.T, D_C)
    A_Bmagnitude = np.linalg.norm(A_B)  
    D_Cmagnitude = np.linalg.norm(D_C)

    cos_theta = dotproduct /  (A_Bmagnitude * D_Cmagnitude)

    return np.arccos(cos_theta) * 180/math.pi

## Gonna calculate
# Neck angle: R shoulder, nose, L_shoulder
# Shoulder join angle:

# %%
data.columns
# Out:
# Index(['participant_id', 'trial_id', 'result', 'landing_x', 'landing_y',
#        'entry_angle', 'ball_x', 'ball_y', 'ball_z', 'R_EYE_x', 'R_EYE_y',
#        'R_EYE_z', 'L_EYE_x', 'L_EYE_y', 'L_EYE_z', 'NOSE_x', 'NOSE_y',
#        'NOSE_z', 'R_EAR_x', 'R_EAR_y', 'R_EAR_z', 'L_EAR_x', 'L_EAR_y',
#        'L_EAR_z', 'R_SHOULDER_x', 'R_SHOULDER_y', 'R_SHOULDER_z',
#        'L_SHOULDER_x', 'L_SHOULDER_y', 'L_SHOULDER_z', 'R_ELBOW_x',
#        'R_ELBOW_y', 'R_ELBOW_z', 'L_ELBOW_x', 'L_ELBOW_y', 'L_ELBOW_z',
#        'R_WRIST_x', 'R_WRIST_y', 'R_WRIST_z', 'L_WRIST_x', 'L_WRIST_y',
#        'L_WRIST_z', 'R_HIP_x', 'R_HIP_y', 'R_HIP_z', 'L_HIP_x', 'L_HIP_y',
#        'L_HIP_z', 'R_KNEE_x', 'R_KNEE_y', 'R_KNEE_z', 'L_KNEE_x', 'L_KNEE_y',
#        'L_KNEE_z', 'R_ANKLE_x', 'R_ANKLE_y', 'R_ANKLE_z', 'L_ANKLE_x',
#        'L_ANKLE_y', 'L_ANKLE_z', 'R_1STFINGER_x', 'R_1STFINGER_y',
#        'R_1STFINGER_z', 'R_5THFINGER_x', 'R_5THFINGER_y', 'R_5THFINGER_z',
# ...

# %%
data_copy = data.copy()

data_copy['RIGHT_ELBOW_ANGLE'] = data_copy.apply(lambda row: angle_finder_shared(A = np.array([row['R_SHOULDER_x'], row['R_SHOULDER_y'], row['R_SHOULDER_z']]), 
                                                                       B = np.array([row['R_ELBOW_x'], row['R_ELBOW_y'], row['R_ELBOW_z']]), 
                                                                       C = np.array([row['R_WRIST_x'], row['R_WRIST_y'], row['R_WRIST_z']]), 
                                                                       D = np.array([row['R_ELBOW_x'], row['R_ELBOW_y'], row['R_ELBOW_z']])), axis=1)

data_copy['LEFT_ELBOW_ANGLE'] = data_copy.apply(lambda row: angle_finder_shared(A = np.array([row['L_SHOULDER_x'], row['L_SHOULDER_y'], row['L_SHOULDER_z']]), 
                                                                       B = np.array([row['L_ELBOW_x'], row['L_ELBOW_y'], row['L_ELBOW_z']]), 
                                                                       C = np.array([row['L_WRIST_x'], row['L_WRIST_y'], row['L_WRIST_z']]), 
                                                                       D = np.array([row['L_ELBOW_x'], row['L_ELBOW_y'], row['L_ELBOW_z']])), axis=1)

data_copy['RIGHT_SHOULDER_ANGLE'] = data_copy.apply(lambda row: angle_finder_shared(A = np.array([row['R_EAR_x'], row['R_EAR_y'], row['R_EAR_z']]), 
                                                                       B = np.array([row['R_SHOULDER_x'], row['R_SHOULDER_y'], row['R_SHOULDER_z']]), 
                                                                       C = np.array([row['R_ELBOW_x'], row['R_ELBOW_y'], row['R_ELBOW_z']]), 
                                                                       D = np.array([row['R_SHOULDER_x'], row['R_SHOULDER_y'], row['R_SHOULDER_z']])), axis=1)

data_copy['LEFT_SHOULDER_ANGLE']= data_copy.apply(lambda row: angle_finder_shared(A = np.array([row['L_EAR_x'], row['L_EAR_y'], row['L_EAR_z']]), 
                                                                       B = np.array([row['L_SHOULDER_x'], row['L_SHOULDER_y'], row['L_SHOULDER_z']]), 
                                                                       C = np.array([row['L_ELBOW_x'], row['L_ELBOW_y'], row['L_ELBOW_z']]), 
                                                                       D = np.array([row['L_SHOULDER_x'], row['L_SHOULDER_y'], row['L_SHOULDER_z']])), axis=1)

data_copy['RIGHT_WRIST_ANGLE']= data_copy.apply(lambda row: angle_finder_shared(A = np.array([row['R_ELBOW_x'], row['R_ELBOW_y'], row['R_ELBOW_z']]), 
                                                                       B = np.array([row['R_WRIST_x'], row['R_WRIST_y'], row['R_WRIST_z']]), 
                                                                       C = np.array([row['R_1STFINGER_x'], row['R_1STFINGER_y'], row['R_1STFINGER_z']]), 
                                                                       D = np.array([row['R_WRIST_x'], row['R_WRIST_y'], row['R_WRIST_z']])), axis=1)

data_copy['LEFT_WRIST_ANGLE'] = data_copy.apply(lambda row: angle_finder_shared(A = np.array([row['L_ELBOW_x'], row['L_ELBOW_y'], row['L_ELBOW_z']]), 
                                                                       B = np.array([row['L_WRIST_x'], row['L_WRIST_y'], row['L_WRIST_z']]), 
                                                                       C = np.array([row['L_1STFINGER_x'], row['L_1STFINGER_y'], row['L_1STFINGER_z']]), 
                                                                       D = np.array([row['L_WRIST_x'], row['L_WRIST_y'], row['L_WRIST_z']])), axis=1)

data_copy['RIGHT_HIP_ANGLE']  = data_copy.apply(lambda row: angle_finder_shared(A = np.array([row['R_SHOULDER_x'], row['R_SHOULDER_y'], row['R_SHOULDER_z']]),
                                                                       B = np.array([row['R_HIP_x'], row['R_HIP_y'], row['R_HIP_z']]), 
                                                                       C = np.array([row['R_KNEE_x'], row['R_KNEE_y'], row['R_KNEE_z']]), 
                                                                       D = np.array([row['R_HIP_x'], row['R_HIP_y'], row['R_HIP_z']])),  axis=1)

data_copy['LEFT_HIP_ANGLE']   = data_copy.apply(lambda row: angle_finder_shared(A = np.array([row['L_SHOULDER_x'], row['L_SHOULDER_y'], row['L_SHOULDER_z']]),
                                                                       B = np.array([row['L_HIP_x'], row['L_HIP_y'], row['L_HIP_z']]), 
                                                                       C = np.array([row['L_KNEE_x'], row['L_KNEE_y'], row['L_KNEE_z']]), 
                                                                       D = np.array([row['L_HIP_x'], row['L_HIP_y'], row['L_HIP_z']])),  axis=1)

data_copy['RIGHT_KNEE_ANGLE'] = data_copy.apply(lambda row: angle_finder_shared(A = np.array([row['R_HIP_x'], row['R_HIP_y'], row['R_HIP_z']]),
                                                                       B = np.array([row['R_KNEE_x'], row['R_KNEE_y'], row['R_KNEE_z']]),
                                                                       C = np.array([row['R_ANKLE_x'], row['R_ANKLE_y'], row['R_ANKLE_z']]), 
                                                                       D =  np.array([row['R_KNEE_x'], row['R_KNEE_y'], row['R_KNEE_z']])), axis=1)

data_copy['LEFT_KNEE_ANGLE']  = data_copy.apply(lambda row: angle_finder_shared(A = np.array([row['L_HIP_x'], row['L_HIP_y'], row['L_HIP_z']]),
                                                                       B = np.array([row['L_KNEE_x'], row['L_KNEE_y'], row['L_KNEE_z']]),
                                                                       C = np.array([row['L_ANKLE_x'], row['L_ANKLE_y'], row['L_ANKLE_z']]), 
                                                                       D =  np.array([row['L_KNEE_x'], row['L_KNEE_y'], row['L_KNEE_z']])), axis=1)

data_copy['RIGHT_ANKLE_ANGLE'] = data_copy.apply(lambda row: angle_finder_shared(A = np.array([row['R_KNEE_x'], row['R_KNEE_y'], row['R_KNEE_z']]), 
                                                                       B = np.array([row['R_ANKLE_x'], row['R_ANKLE_y'], row['R_ANKLE_z']]), 
                                                                       C = np.array([row['R_1STTOE_x'], row['R_1STTOE_y'], row['R_1STTOE_z']]), 
                                                                       D = np.array([row['R_ANKLE_x'], row['R_ANKLE_y'], row['R_ANKLE_z']])), axis=1)

data_copy['LEFT_ANKLE_ANGLE']  = data_copy.apply(lambda row: angle_finder_shared(A = np.array([row['L_KNEE_x'], row['L_KNEE_y'], row['L_KNEE_z']]), 
                                                                       B = np.array([row['L_ANKLE_x'], row['L_ANKLE_y'], row['L_ANKLE_z']]), 
                                                                       C = np.array([row['L_1STTOE_x'], row['L_1STTOE_y'], row['L_1STTOE_z']]), 
                                                                       D = np.array([row['L_ANKLE_x'], row['L_ANKLE_y'], row['L_ANKLE_z']])), axis=1)

# %%
## Body Velocity Variables:
# Need to groupby and then apply np.roll and then calculate it probably using next - old / 30 like the one above


def velocity_calc(data, column, groupby_col='trial_id'):
    """ 
    Does some quick velocity calculations for different bodyparts. 
    Follows this process:
    1. Groupby by the groupby object
    2. runs pd.shift() method for the column with the specific movement_axis (x, y, z, or all)
    3. differences the 2 
    4. divides by 30 to give us velocity
    
    Args:
        data (pd.DataFrame): the dataset
        column (list of strings): Columns
        groupby_col (string or list of strings): what to groupby by (eventually may have to factor multiple features)
    
    returns:
        Nonetype
    """
    group = data.groupby(groupby_col)
    
    for col in column:
        shifted_col = group[col].shift(1)
        data[f'VELOCITY_{col}'] = (data[col] - shifted_col) * 30
        
    return data
    


velocity_calc(data=data_copy, column = ['R_SHOULDER_x', 'R_SHOULDER_y', 'R_SHOULDER_z',
       'L_SHOULDER_x', 'L_SHOULDER_y', 'L_SHOULDER_z', 'R_ELBOW_x',
       'R_ELBOW_y', 'R_ELBOW_z', 'L_ELBOW_x', 'L_ELBOW_y', 'L_ELBOW_z',
       'R_WRIST_x', 'R_WRIST_y', 'R_WRIST_z', 'L_WRIST_x', 'L_WRIST_y',
       'L_WRIST_z', 'R_HIP_x', 'R_HIP_y', 'R_HIP_z', 'L_HIP_x', 'L_HIP_y',
       'L_HIP_z', 'R_KNEE_x', 'R_KNEE_y', 'R_KNEE_z', 'L_KNEE_x', 'L_KNEE_y',
       'L_KNEE_z', 'R_ANKLE_x', 'R_ANKLE_y', 'R_ANKLE_z', 'L_ANKLE_x',
       'L_ANKLE_y', 'L_ANKLE_z'])
# Out:
#       participant_id trial_id  result  landing_x  landing_y  entry_angle  \
# 0              P0001    T0001  missed       7.15     12.755         40.9
# 1              P0001    T0001  missed       7.15     12.755         40.9
# 2              P0001    T0001  missed       7.15     12.755         40.9
# 3              P0001    T0001  missed       7.15     12.755         40.9
# 4              P0001    T0001  missed       7.15     12.755         40.9
# ...              ...      ...     ...        ...        ...          ...
# 29995          P0001    T0125    made      -2.55      7.550         45.3
# 29996          P0001    T0125    made      -2.55      7.550         45.3
# 29997          P0001    T0125    made      -2.55      7.550         45.3
# 29998          P0001    T0125    made      -2.55      7.550         45.3
# 29999          P0001    T0125    made      -2.55      7.550         45.3
#
#        ball_x  ball_y  ball_z  R_EYE_x  ...  VELOCITY_R_KNEE_z  \
# ...

# %% [markdown]
# ## Let's make some nice plots and try to motivate some investigation

# %%
## Let's just look at the player's summary statsistics
result_counts = data_copy['result'].value_counts() / 240
result_counts.plot(kind = 'bar')
plt.title('Outcome Distribution (Hits vs Misses)')
plt.xlabel('Result')
plt.ylabel('Count')
plt.show()

# %%
plt.hexbin(data_copy['landing_x'], data_copy['landing_y'], gridsize=10, cmap='Blues')
plt.title('Heatmap of Ball Landing Positions')
plt.xlabel('Landing X')
plt.ylabel('Landing Y')
plt.colorbar(label='Count')
plt.show()

# %%
plt.scatter(data_copy.groupby('trial_id')['entry_angle'].head(1), data_copy.groupby('trial_id')['landing_x'].head(1), alpha=0.6, color='purple')
plt.title('Landing X vs Entry Angle')
plt.xlabel('Entry Angle (degrees)')
plt.ylabel('Landing X Position')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x=data_copy['result'], y=data_copy['entry_angle'], palette='Set2')
plt.title('Entry Angle Distribution by Result (Hit vs Miss)')
plt.xlabel('Result')
plt.ylabel('Entry Angle')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1880\3463163898.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=data_copy['result'], y=data_copy['entry_angle'], palette='Set2')

# %%
plt.hist(data_copy['VELOCITY_R_WRIST_x'], bins=30, color='lightblue', edgecolor='black')
plt.title('Right Wrist Velocity Distribution')
plt.xlabel('Velocity')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(data_copy['VELOCITY_R_WRIST_y'], bins=30, color='lightblue', edgecolor='black')
plt.title('Right Wrist Velocity Distribution')
plt.xlabel('Velocity')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(data_copy['VELOCITY_R_WRIST_z'], bins=30, color='lightblue', edgecolor='black')
plt.title('Right Wrist Velocity Distribution')
plt.xlabel('Velocity')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# This makes sense. Zero is the center but we also have a second mode near the 5.0 this is probably related to the arm raising motion but it is relatively slow because the player is aiming while doing so. But it would obviously be helpful to do so specificlally during the time we are releasing the ball. Let's just check the timeseries of both the ball and the wrists.

# %%
# %matplotlib inline

# %%
# %matplotlib inline 

ball_data = data_copy[data_copy['trial_id'] == 'T0001']

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot for ball
ax.scatter(ball_data['ball_x'], ball_data['ball_y'], ball_data['ball_z'], 
           c='red', label='Ball', s=30, alpha=0.7)

# Scatter plot for right wrist
ax.scatter(ball_data['R_WRIST_x'], ball_data['R_WRIST_y'], ball_data['R_WRIST_z'], 
           c='blue', label='Right Wrist', s=30, alpha=0.7)

# Set axis labels
ax.set_xlabel('X Position')
ax.set_ylabel('Y Position')
ax.set_zlabel('Z Position')

# Set title and legend
plt.title('3D Position of Ball and Wrists')
ax.legend()
plt.show()

# %% [markdown]
# Can't rotate this with VS Code. But let's try to figure this out anyway.

# %%
## let's make this simpler, let's plot the distance between these 2 things, and then plot that

wrist_ball_dist = ((data_copy['ball_x']**2  +  data_copy['ball_y']**2 + data_copy['ball_z']**2) - (data_copy['R_WRIST_x']**2 + data_copy['R_WRIST_y']**2  + data_copy['R_WRIST_z']**2))**.5

# %%
wrist_ball_dist = wrist_ball_dist.dropna()

fig = plt.figure(figsize=(10, 8))
wrist_ball_dist.plot()
# Out:
# <Axes: >

# %% [markdown]
# Some Values close to 0. We can check the properties using a histogram

# %%
plt.hist(wrist_ball_dist, bins=25, color='lightblue', edgecolor='black')
plt.title('Wrist and Ball distance Distribution')
plt.xlabel('distance')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Seems to be less than like 3-4. Maybe we can try to plot this for a singular shot and then try to make some sense about how to define the variables.

# %%
wrist_ball_dist = ((ball_data['ball_x']**2  +  ball_data['ball_y']**2 + ball_data['ball_z']**2) - (ball_data['R_WRIST_x']**2 + ball_data['R_WRIST_y']**2  + ball_data['R_WRIST_z']**2))**.5

wrist_ball_dist = wrist_ball_dist.dropna()

fig = plt.figure(figsize=(10, 8))
wrist_ball_dist.plot()
# Out:
# <Axes: >

# %% [markdown]
# So it seems like when it is less than 5, we can assume that the shooter is basically holding the ball. The spike at 120 is because the shooter dribbled the ball before shooting.

# %%
data_copy['BALL_IN_HAND'] = np.where(data_copy['ball_wrist_dist'] < 5.0, True, False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ball_wrist_dist'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
plt.hist(data_copy[data_copy['BALL_IN_HAND'] == True]['VELOCITY_R_WRIST_z'], bins=30, color='lightblue', edgecolor='black')
plt.title('Right Wrist Velocity Distribution')
plt.xlabel('Velocity')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Might need to look more specifically at the ball release frames. However, we can now analyse the correlations of certain body parts when the ball is and not in the hand.

# %%
## Before we look at correlations of certain body parts based on the ball location. Let's start with simply calculating the XCF to understand 
# the xross correation function of the data. But I am not doing the entire unit root tests, yule walker stuff so might not be the most acc

## The idea is to calculate the cross correlation and then average it out across all 125 shots. We can do this with groupby!
# First adding a timestep column to make the data more timeseries

data_copy['FrameStep'] = data_copy.groupby(['trial_id']).cumcount() + 1  ## Not using this now but in the future
def calculate_XCF(group, col_1, col_2):
    group_normalized = (group[[col_1, col_2]] - group[[col_1, col_2]].mean()) / group[[col_1, col_2]].std()
    cross_corr = np.correlate(group_normalized[col_1], group_normalized[col_2], mode='full')
    
    return pd.Series(cross_corr)


groups = data_copy.groupby(['trial_id'])
cross_corr_results = data_copy.groupby(['trial_id']).apply(calculate_XCF, col_1='R_SHOULDER_x', col_2='R_ELBOW_x')
cross_corr_results_array = np.array(cross_corr_results)
mean_cross_corr = np.mean(cross_corr_results_array, axis=0)

lags = np.arange(-240 + 1, 240)
plt.plot(lags, mean_cross_corr)
plt.title('Average Cross-correlation (feature_1 vs feature_2) Across 125 Trials')
plt.xlabel('Lag')
plt.ylabel('Cross-correlation')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_28656\3599657440.py:16: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   cross_corr_results = data_copy.groupby(['trial_id']).apply(calculate_XCF, col_1='R_SHOULDER_x', col_2='R_ELBOW_x')

# %%
## Before we look at correlations of certain body parts based on the ball location. Let's start with simply calculating the XCF to understand 
# the xross correation function of the data. But I am not doing the entire unit root tests, yule walker stuff so might not be the most acc

## The idea is to calculate the cross correlation and then average it out across all 125 shots. We can do this with groupby!
# First adding a timestep column to make the data more timeseries

data_copy['FrameStep'] = data_copy.groupby(['trial_id']).cumcount() + 1  ## Not using this now but in the future
def calculate_XCF(group, col_1, col_2):
    group_normalized = (group[[col_1, col_2]] - group[[col_1, col_2]].mean()) / group[[col_1, col_2]].std()
    cross_corr = np.correlate(group_normalized[col_1], group_normalized[col_2], mode='full')
    
    return pd.Series(cross_corr)


groups = data_copy.groupby(['trial_id'])
cross_corr_results = data_copy.groupby(['trial_id']).apply(calculate_XCF, col_1='L_SHOULDER_x', col_2='L_ELBOW_x')
cross_corr_results_array = np.array(cross_corr_results)
mean_cross_corr = np.mean(cross_corr_results_array, axis=0)

lags = np.arange(-240 + 1, 240)
plt.plot(lags, mean_cross_corr)
plt.title('Average Cross-correlation (feature_1 vs feature_2) Across 125 Trials')
plt.xlabel('Lag')
plt.ylabel('Cross-correlation')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_28656\2995951257.py:16: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   cross_corr_results = data_copy.groupby(['trial_id']).apply(calculate_XCF, col_1='L_SHOULDER_x', col_2='L_ELBOW_x')

# %%
## Before we look at correlations of certain body parts based on the ball location. Let's start with simply calculating the XCF to understand 
# the xross correation function of the data. But I am not doing the entire unit root tests, yule walker stuff so might not be the most acc

## The idea is to calculate the cross correlation and then average it out across all 125 shots. We can do this with groupby!
# First adding a timestep column to make the data more timeseries

data_copy['FrameStep'] = data_copy.groupby(['trial_id']).cumcount() + 1  ## Not using this now but in the future
def calculate_XCF(group, col_1, col_2):
    group_normalized = (group[[col_1, col_2]] - group[[col_1, col_2]].mean()) / group[[col_1, col_2]].std()
    cross_corr = np.correlate(group_normalized[col_1], group_normalized[col_2], mode='full')
    
    return pd.Series(cross_corr)


groups = data_copy.groupby(['trial_id'])
cross_corr_results = data_copy.groupby(['trial_id']).apply(calculate_XCF, col_1='R_HIP_z', col_2='R_WRIST_z')
cross_corr_results_array = np.array(cross_corr_results)
mean_cross_corr = np.mean(cross_corr_results_array, axis=0)

lags = np.arange(-240 + 1, 240)
plt.plot(lags[230:250], mean_cross_corr[230:250])
plt.title('Average Cross-correlation (R_HIP_z vs R_WRIST_z) Across 125 Trials')
plt.xlabel('Lag')
plt.ylabel('Cross-correlation')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_28656\2209830941.py:16: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   cross_corr_results = data_copy.groupby(['trial_id']).apply(calculate_XCF, col_1='R_HIP_z', col_2='R_WRIST_z')

# %% [markdown]
# So the peak is actually at around 5. So this basically means that the 5th lag so the movemnt 5 frames before has the strongest influence. Basically, the movement begins with the hips and then in 5 frames the player shoots the ball.

# %% [markdown]
# ## Correlations at the point of shooting.
# We can also focus specifically on the specific tie that the player has the ball. This would give us more insight into the behaviour of the player at the movement of shooting. I will do this later

# %% [markdown]
# ## Angular Analysis
# How the angles behave is also important but I will do this later

# %% [markdown]
# # Shapelet Prototyping

# %%
data_copy_copy = data_copy.copy()

data_copy_copy.columns[:49]
# Out:
# Index(['participant_id', 'trial_id', 'result', 'landing_x', 'landing_y',
#        'entry_angle', 'ball_x', 'ball_y', 'ball_z', 'R_EYE_x', 'R_EYE_y',
#        'R_EYE_z', 'L_EYE_x', 'L_EYE_y', 'L_EYE_z', 'NOSE_x', 'NOSE_y',
#        'NOSE_z', 'R_EAR_x', 'R_EAR_y', 'R_EAR_z', 'L_EAR_x', 'L_EAR_y',
#        'L_EAR_z', 'R_SHOULDER_x', 'R_SHOULDER_y', 'R_SHOULDER_z',
#        'L_SHOULDER_x', 'L_SHOULDER_y', 'L_SHOULDER_z', 'R_ELBOW_x',
#        'R_ELBOW_y', 'R_ELBOW_z', 'L_ELBOW_x', 'L_ELBOW_y', 'L_ELBOW_z',
#        'R_WRIST_x', 'R_WRIST_y', 'R_WRIST_z', 'L_WRIST_x', 'L_WRIST_y',
#        'L_WRIST_z', 'R_HIP_x', 'R_HIP_y', 'R_HIP_z', 'L_HIP_x', 'L_HIP_y',
#        'L_HIP_z', 'R_KNEE_x'],
#       dtype='object')

# %% [markdown]
# Tensorflow isn't working. Let me see what I can do fuck it i'll just define everything myself

# %%
## First let's define the timeseries dataset:
## Which means we have Q ordered datapoints, of I classes 
## I will save this as a 

def DatasetTimeseries(data, col):
    """
    This is a function to convert to the appropriate timeseries format. I realise this is a oneliner but eh
    
    For now this will a stricly univariate timeseries. I will scale this as needed

    fuck it imma pytorch this bitch

    args:
        data (pd.Dataset): The dataset we need to convert to the appropriate format (this should ideally have a unique row for each frame)
        cols (string): This is a list of strings of the columns we need to preserve (THis should just be one specific column)

    returns:
        ts_data (pd.Dataset): The dataset that is in the format Q ordered data (In our case 240) * timeseries (125)
        results (pd.Series): The results which should be a binary output with 125 observations
    """
    data_output = data[['trial_id', col]].groupby(['trial_id'])[[col]].apply(lambda df: df.reset_index(drop = True)).unstack().reset_index('trial_id')
    data_output.columns = data_output.columns.droplevel(0)
    data_output = data_output.drop('', axis= 1) 

    results = data[['trial_id', 'result']].groupby(['trial_id'])['result'].head(1)

    return data_output, results

# %%
data_try, results = DatasetTimeseries(data_copy, 'RIGHT_ELBOW_ANGLE')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class ShapletLearner(nn.Module):
    def __init__(self, num_shapelet, len_shapelet, input_size, num_classes, alpha_precision, kmeans_centroids):
        super().__init__()

        assert input_size % len_shapelet  == 0 ## I do not want to deal with padding although it might not be needed at all. 
        self.L = num_shapelet ## Using the paper's terminalogy
        self.K = len_shapelet

        self.Q = input_size
        self.I = num_classes

        self.alpha = alpha_precision

        if kmeans_centroids is not None:
            assert kmeans_centroids.shape == (num_shapelet, len_shapelet), \
                "KMeans centroids must have the shape (num_shapelets, len_shapelet)."
            self.shapelets = nn.ParameterList(
                [nn.Parameter(torch.tensor(centroid, dtype=torch.float32)) for centroid in kmeans_centroids]
            )
        else:
            # Random initialization if no KMeans centroids are provided
            self.shapelets = nn.ParameterList(nn.Parameter(torch.randn(self.K)) for _ in range(num_shapelet))
        
       #self.shapelets = nn.ParameterList(nn.Parameter(torch.randn(self.K)) for _ in range(num_shapelet))
        self.fc1 = nn.Linear(self.L, 2)

        self.loss_fn = torch.nn.CrossEntropyLoss() ## This is what they used not sure why not BCE with logit but eh

    def _compute_shapelet_dist(self, ts):
        shapelet_distances = [] 
        for shapelet in self.shapelets:
            num_segments = self.Q - self.K + 1
            distances = []
            for j in range(num_segments):
                segment = ts[:, j:j+self.K] 
                segment = segment
                dist = torch.mean((segment - shapelet)**2, dim = 1)
                if torch.isnan(dist).any():
                    print("NaN detected in distance calculation")
                distances.append(dist)
            distances = torch.stack(distances, dim = 1)

            hard_min, _ = torch.min(distances, dim=1)
            if torch.isnan(hard_min).any():
                print("NaN detected in min operation") 
            shapelet_distances.append(hard_min)

        result =  torch.stack(shapelet_distances, dim = 1) 
        if torch.isnan(result).any():
            print("NaN detected in final Shapelet distance")
        return torch.stack(shapelet_distances, dim = 1) 

    def forward(self, ts):
        ts = ts.float()
        shaplet_distances = self._compute_shapelet_dist(ts)
        output = self.fc1(shaplet_distances)
        return output
    
    def loss(self, pred, labels):
        return self.loss_fn(pred, labels)

# %%
### Dataset object:
from torch.utils.data import Dataset, DataLoader

class TSDataset(Dataset):
    def __init__(self, ts_data, labels):
        self.time_series = ts_data
        self.labels = labels
    
    def __len__(self):
        return len(self.time_series)
    
    def __getitem__(self, idx):
        return self.time_series[idx], self.labels[idx]

# %%
def train_shaplet_model(model, train_loader, optimizer, epochs = 100):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)

    for epoch in range(epochs):
        model.train()
        total_loss = 0
        
        for time_series, labels in train_loader:
            time_series, labels = time_series.to(device), labels.to(device)
            optimizer.zero_grad()
            predictions = model(time_series)
            loss = model.loss_fn(predictions, labels)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        print(f'Epoch [{epoch + 1}/{epochs}], Loss: {total_loss / len(train_loader)}')

# %%
from sklearn.cluster import KMeans

def extract_segments(timeseries_data, segment_length):
    _, time_series_length = timeseries_data.shape
    segments = []

    # Loop over all time series
    for ts in timeseries_data:
        num_segments = time_series_length - segment_length + 1
        for i in range(num_segments):
            segment = ts[i:i+segment_length]
            segments.append(segment)
    
    return np.array(segments)


def shapelet_initialization(timeseries_data, num_shapelets, shapelet_length):
    segments = extract_segments(timeseries_data, shapelet_length)
    kmeans = KMeans(n_clusters=num_shapelets, random_state=42)
    kmeans.fit(segments)
    return kmeans.cluster_centers_

# %%
timeseries_dataset = torch.tensor(data_try.values)
labels = torch.tensor(results.map({'missed': 0, 'made':1}).values) 

trial = TSDataset(ts_data = timeseries_dataset, labels=labels)
train_loader = DataLoader(trial, batch_size=32, shuffle=True)


num_shapelets = 10 
shapelet_lengths = 10
input_size = 240
num_classes = 2  
alpha = 1
lambda_w = 0.1
epochs = 1000
kmeans_centroids = shapelet_initialization(timeseries_dataset[:50], num_shapelets, shapelet_lengths)

model = ShapletLearner(num_shapelets, shapelet_lengths, input_size, num_classes, alpha, kmeans_centroids)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
train_shaplet_model(model, train_loader, optimizer, epochs)
# Out:
# Epoch [1/1000], Loss: 3.400159001350403
# Epoch [2/1000], Loss: 2.339726746082306
# Epoch [3/1000], Loss: 1.6259730160236359
# Epoch [4/1000], Loss: 1.0684246122837067
# Epoch [5/1000], Loss: 0.912679135799408
# Epoch [6/1000], Loss: 0.939323827624321
# Epoch [7/1000], Loss: 0.8618971109390259
# Epoch [8/1000], Loss: 0.705666571855545
# Epoch [9/1000], Loss: 0.6616611480712891
# Epoch [10/1000], Loss: 0.6761661171913147
# Epoch [11/1000], Loss: 0.6428653821349144
# Epoch [12/1000], Loss: 0.6617306917905807
# Epoch [13/1000], Loss: 0.6326389759778976
# Epoch [14/1000], Loss: 0.6887294873595238
# Epoch [15/1000], Loss: 0.6797977238893509
# Epoch [16/1000], Loss: 0.651410385966301
# Epoch [17/1000], Loss: 0.6028732284903526
# Epoch [18/1000], Loss: 0.615919217467308
# Epoch [19/1000], Loss: 0.5865306854248047
# Epoch [20/1000], Loss: 0.5991382896900177
# Epoch [21/1000], Loss: 0.5904860571026802
# Epoch [22/1000], Loss: 0.5802832096815109
# Epoch [23/1000], Loss: 0.5883131325244904
# ...

# %%
kmeans_centroids= shapelet_initialization(timeseries_dataset, num_shapelets, shapelet_lengths)
kmeans_centroids
# Out:
# array([[ 80.15020527,  79.80476658,  81.5933405 ,  85.85151735,
#          92.60101398, 101.43777807, 111.5380429 , 121.78531359,
#         131.08408165, 138.63259239],
#        [150.34239902, 151.74147714, 152.85807756, 153.62013532,
#         154.01244821, 154.0676063 , 153.83909884, 153.38116587,
#         152.73912161, 151.9489109 ],
#        [ 98.05195854,  97.08656047,  96.15958183,  95.28793739,
#          94.51250367,  93.87681756,  93.39862154,  93.06888489,
#          92.8606943 ,  92.72998753],
#        [143.26550832, 138.85621341, 132.91028331, 125.62171413,
#         117.24317774, 108.21521021,  99.28775429,  91.42683999,
#          85.63406542,  82.76045434],
#        [147.74767041, 146.931686  , 145.88902298, 144.59875724,
#         143.05285877, 141.25480338, 139.22131182, 136.96179424,
#         134.46991753, 131.75674047],
#        [ 90.39758868,  98.83338154, 109.40561488, 120.94821402,
#         132.11968443, 141.79681281, 149.29169421, 154.37920167,
# ...

# %%
model.eval()
# Out:
# ShapletLearner(
#   (shapelets): ParameterList(
#       (0): Parameter containing: [torch.float32 of size 15]
#       (1): Parameter containing: [torch.float32 of size 15]
#       (2): Parameter containing: [torch.float32 of size 15]
#   )
#   (fc1): Linear(in_features=3, out_features=2, bias=True)
#   (loss_fn): CrossEntropyLoss()
# )

# %%
plt.plot(torch.tensor(model.shapelets[0]))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1880\1083364358.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   plt.plot(torch.tensor(model.shapelets[0]))

# %%
plt.plot(torch.tensor(model.shapelets[1]))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1880\1485905588.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   plt.plot(torch.tensor(model.shapelets[1]))

# %%
plt.plot(torch.tensor(model.shapelets[2]))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1880\3841505259.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   plt.plot(torch.tensor(model.shapelets[2]))

# %%
plt.plot(torch.tensor(model.shapelets[3]))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1880\432247398.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   plt.plot(torch.tensor(model.shapelets[3]))

# %%
plt.plot(torch.tensor(model.shapelets[4]))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1880\246381517.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   plt.plot(torch.tensor(model.shapelets[4]))

# %%
plt.plot(torch.tensor(model.shapelets[5]))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1880\3073509145.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   plt.plot(torch.tensor(model.shapelets[5]))

# %%
plt.plot(torch.tensor(model.shapelets[6]))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1880\3106723175.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   plt.plot(torch.tensor(model.shapelets[6]))

# %%
plt.plot(torch.tensor(model.shapelets[7]))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1880\4292818357.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   plt.plot(torch.tensor(model.shapelets[7]))

# %%
plt.plot(torch.tensor(model.shapelets[8]))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1880\3455632093.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   plt.plot(torch.tensor(model.shapelets[8]))

# %%
plt.plot(torch.tensor(model.shapelets[9]))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1880\1268712433.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   plt.plot(torch.tensor(model.shapelets[9]))

# %%
plt.plot(kmeans_centroids[3])

# %%
# Out:
# tensor([ 0.0456, -0.4678, -0.3190, -0.0762, -0.6503])

# %%
import math
math.exp(-100*7)
# Out:
# 9.85967654375977e-305

# %%
model.eval()
# Out:
# ShapletLearner(
#   (shapelets): ParameterList(
#       (0): Parameter containing: [torch.float32 of size 10]
#       (1): Parameter containing: [torch.float32 of size 10]
#       (2): Parameter containing: [torch.float32 of size 10]
#       (3): Parameter containing: [torch.float32 of size 10]
#       (4): Parameter containing: [torch.float32 of size 10]
#       (5): Parameter containing: [torch.float32 of size 10]
#       (6): Parameter containing: [torch.float32 of size 10]
#       (7): Parameter containing: [torch.float32 of size 10]
#       (8): Parameter containing: [torch.float32 of size 10]
#       (9): Parameter containing: [torch.float32 of size 10]
#   )
#   (fc1): Linear(in_features=10, out_features=2, bias=True)
#   (loss_fn): CrossEntropyLoss()
# )
